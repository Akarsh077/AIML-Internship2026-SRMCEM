# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
image = np.full((16,16,3),250,dtype = 'uint8')
image[4:10,4:5] = [255,0,0]
image[4:10,5:6] = [0,255,0]
cv2.imshow('image',image)
cv2.imwrite('image.jpg',image)
# Out:
# True

# %% [markdown]
# ## Computer Vision

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.12.0

# %%
import numpy as np
import matplotlib.pyplot as plt
image = np.full((1600,1600,3),140,dtype='uint8')
image[400:500, 400:1000] = [51,153,255]
image[600:700, 400:1000] = [0, 128, 0]
cv2.imshow('image',image)
cv2.imwrite('image.jpg',image)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
image = cv2.imread('demo.jpg')
print(type(image))
image = cv2.flip(image,0)
r,b,g = cv2.split(image)
cv2.imshow('image',b)
cv2.waitKey(5000)
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(r, cmap='jet')

# %%
image = cv2.imread('demo.jpg',0)
image = cv2.GaussianBlur(image,(5,5),0)
threshold_image, th = cv2.threshold(image, 157, 255,cv2.THRESH_TOZERO)
th = cv2.putText(th,'Threashold Image',(100,300),cv2.FONT_HERSHEY_SIMPLEX,1,(25,255,25),2)
th = cv2.circle(th, (300,300),100,(255,0,0),5)
cv2.imshow('image',th)

cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
edge_detected_image = cv2.Canny(image, 100, 200)
cv2.imshow('image', edge_detected_image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %% [markdown]
# ## cifer data using CNN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D
from keras.datasets import cifar10
(x_train, y_train),(x_test,y_test) = cifar10.load_data()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 5
#       1 import tensorflow as tf
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Dense,Conv2D
#       4 from keras.datasets import cifar10
# ----> 5 (x_train, y_train),(x_test,y_test) = cifar10.load_data()
#
# File d:\Envt\envYOLO\Lib\site-packages\keras\src\datasets\cifar10.py:70, in load_data()
#      68 dirname = "cifar-10-batches-py-target"
#      69 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 70 path = get_file(
#      71     fname=dirname,
#      72     origin=origin,
#      73     extract=True,
#      74     file_hash=(  # noqa: E501
#      75         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      76     ),
#      77 )
#      79 num_train_samples = 50000
# ...

# %%
print(x_train.shape)
cifar10_classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(x_train.shape)
#       2 cifar10_classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
#
# NameError: name 'x_train' is not defined
