# %%
import math
from sklearn.feature_extraction.text import TfidfTransformer
doc = ['The cat set on the mat','The dog played in the park','Cats and dogs are great pets']
tfid = TfidVectorizer()
result = tfid.fit_transform(doc)
print(result.get_fu)

# %%
import nltk.tokenize import sent_tokenize
text = """Characters """
